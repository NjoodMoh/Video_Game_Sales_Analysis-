# %% [markdown]
# ## Appendex
# - Cick on the links:
#     >1. <a href=#imports>Imports</a>
#     >2. <a href=#loaddata>Load Data</a>
#     >3. <a href=#dataformating>Data Formating</a>
#     >4. <a href=#validat>Validate Assumption(Optional If exist)</a>
#     >5. <a href=#Expl>Exploratory Data Analysis (Uni-Variable)</a>
#     >6. <a href=#Explo>Exploratory Data Analysis (Multi-Variable_Relationship)</a>
#     >7. <a href=#Ques> Questions & Insights </a>
#     >8. <a href=#Conc> Conculsion </a>

# %% [markdown]
# ## Abstract

# %% [markdown]
# Who doesn't like video games? Video games have become a favorite pastime for most of us. Video
# games are a billion-dollar business and have been for many years. Now imagine being able to analyze
# the sales trends for the popular Nintendo games and many more such platforms. How cool would it be!

# %% [markdown]
# ## Design

# %% [markdown]
# Data provided in this project by Kaggle & data. world . In this module, we will be laying the foundation for our
# analysis by processing and exploring a large amount of data on video game sales. The dataset contains
# information regarding the sales of video games across various regions like North America, Europe, Japan
# and globally, while also giving information regarding the Names, Publishers and Platforms. This dataset
# has been made available thanks to Kaggle which is the home for many such datasets and competitions.

# %% [markdown]
# # <a name='imports' > Import Libraries </a>

# %%
#Importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns 
# this statement allows the visuals to render within your Jupyter Notebook
# %matplotlib inline 
import plotly.graph_objects as go

# %% [markdown]
# # <a name='loaddata' > Load Data </a>

# %%
df1 = pd.read_csv('VGglob.csv',na_values='tbd')

# %%
df1.head()
# Out:
#                                    name        platform release_date  \
# 0  The Legend of Zelda: Ocarina of Time     Nintendo 64    23-Nov-98
# 1              Tony Hawk's Pro Skater 2     PlayStation    20-Sep-00
# 2                   Grand Theft Auto IV   PlayStation 3    29-Apr-08
# 3                           SoulCalibur       Dreamcast     8-Sep-99
# 4                   Grand Theft Auto IV        Xbox 360    29-Apr-08
#
#                                              summary  meta_score  user_review
# 0  As a young boy, Link is tricked by Ganondorf, ...          99          9.1
# 1  As most major publishers' development efforts ...          98          7.4
# 2  [Metacritic's 2008 PS3 Game of the Year; Also ...          98          7.7
# 3  This is a tale of souls and swords, transcendi...          98          8.4
# 4  [Metacritic's 2008 Xbox 360 Game of the Year; ...          98          7.9

# %%
df2 = pd.read_csv('vgsalesGlobale.csv',na_values='tbd')

# %%
df2.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df2.columns
# Out:
# Index(['Rank', 'name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
eu = df2[['Rank', 'name', 'Platform', 'Year', 'Genre', 'Publisher',
       'EU_Sales']].copy()
na = df2[['Rank', 'name', 'Platform', 'Year', 'Genre', 'Publisher',
       'NA_Sales']].copy()
jp = df2[['Rank', 'name', 'Platform', 'Year', 'Genre', 'Publisher',
       'JP_Sales']].copy()
other = df2[['Rank', 'name', 'Platform', 'Year', 'Genre', 'Publisher',
       'Other_Sales']].copy()
gl = df2[['Rank', 'name', 'Platform', 'Year', 'Genre', 'Publisher',
       'Global_Sales']].copy()

# %%
for region, df_new in zip(["EU","NA","JP","Other","Global"],[eu,na,jp,other,gl]):
    df_new["Region"] = region
    df_new.columns = ['Rank', 'name', 'Platform', 'Year', 'Genre', 'Publisher', 'Sales','Region']

# %%
regions_df = pd.concat([eu,na,jp,other,gl])

# %%
regions_df[regions_df.name == "Wii Sports"]
# Out:
#    Rank        name Platform    Year   Genre Publisher  Sales  Region
# 0     1  Wii Sports      Wii  2006.0  Sports  Nintendo  29.02      EU
# 0     1  Wii Sports      Wii  2006.0  Sports  Nintendo  41.49      NA
# 0     1  Wii Sports      Wii  2006.0  Sports  Nintendo   3.77      JP
# 0     1  Wii Sports      Wii  2006.0  Sports  Nintendo   8.46   Other
# 0     1  Wii Sports      Wii  2006.0  Sports  Nintendo  82.74  Global

# %%
sns.lineplot(data=regions_df[~(regions_df.isin(["Global", "Other"])) ], x="Year", y="Sales", hue="Region")
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Sales'>

# %% [markdown]
# # <a name='dataformating' > Data Formating </a>

# %%
df1.drop('summary', axis=1, inplace=True)

# %%
df1.head()
# Out:
#                                    name        platform release_date  \
# 0  The Legend of Zelda: Ocarina of Time     Nintendo 64    23-Nov-98
# 1              Tony Hawk's Pro Skater 2     PlayStation    20-Sep-00
# 2                   Grand Theft Auto IV   PlayStation 3    29-Apr-08
# 3                           SoulCalibur       Dreamcast     8-Sep-99
# 4                   Grand Theft Auto IV        Xbox 360    29-Apr-08
#
#    meta_score  user_review
# 0          99          9.1
# 1          98          7.4
# 2          98          7.7
# 3          98          8.4
# 4          98          7.9

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18800 entries, 0 to 18799
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          18800 non-null  object
#  1   platform      18800 non-null  object
#  2   release_date  18800 non-null  object
#  3   meta_score    18800 non-null  int64
#  4   user_review   17435 non-null  float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 734.5+ KB

# %%
df2.rename(columns = {'Name': 'name'}, inplace =True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# ## Merge Data

# %%
df = pd.merge(df1, df2, on='name', how='inner')

# %%
df.head()
# Out:
#                                    name      platform release_date  \
# 0  The Legend of Zelda: Ocarina of Time   Nintendo 64    23-Nov-98
# 1  The Legend of Zelda: Ocarina of Time   Nintendo 64    23-Nov-98
# 2              Tony Hawk's Pro Skater 2   PlayStation    20-Sep-00
# 3              Tony Hawk's Pro Skater 2   PlayStation    20-Sep-00
# 4              Tony Hawk's Pro Skater 2   PlayStation    20-Sep-00
#
#    meta_score  user_review  Rank Platform    Year   Genre   Publisher  \
# 0          99          9.1    95      N64  1998.0  Action    Nintendo
# 1          99          9.1   269      3DS  2011.0  Action    Nintendo
# 2          98          7.4   226       PS  2000.0  Sports  Activision
# 3          98          7.4  1713      GBA  2001.0  Sports  Activision
# 4          98          7.4  2707      N64  2001.0  Sports  Activision
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0      4.10      1.89      1.45         0.16          7.60
# ...

# %%
df.head(20)
# Out:
#                                     name           platform release_date  \
# 0   The Legend of Zelda: Ocarina of Time        Nintendo 64    23-Nov-98
# 1   The Legend of Zelda: Ocarina of Time        Nintendo 64    23-Nov-98
# 2               Tony Hawk's Pro Skater 2        PlayStation    20-Sep-00
# 3               Tony Hawk's Pro Skater 2        PlayStation    20-Sep-00
# 4               Tony Hawk's Pro Skater 2        PlayStation    20-Sep-00
# 5               Tony Hawk's Pro Skater 2          Dreamcast     6-Nov-00
# 6               Tony Hawk's Pro Skater 2          Dreamcast     6-Nov-00
# 7               Tony Hawk's Pro Skater 2          Dreamcast     6-Nov-00
# 8               Tony Hawk's Pro Skater 2   Game Boy Advance    30-May-01
# 9               Tony Hawk's Pro Skater 2   Game Boy Advance    30-May-01
# 10              Tony Hawk's Pro Skater 2   Game Boy Advance    30-May-01
# 11              Tony Hawk's Pro Skater 2                 PC    25-Oct-00
# ...

# %%
# Check null value

# %%
df.isna().sum()
# Out:
# name               0
# platform           0
# release_date       0
# meta_score         0
# user_review     1079
# Rank               0
# Platform           0
# Year             411
# Genre              0
# Publisher          9
# NA_Sales           0
# EU_Sales           0
# JP_Sales           0
# Other_Sales        0
# Global_Sales       0
# dtype: int64

# %%
sum(df.duplicated())
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18607 entries, 0 to 18606
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          18607 non-null  object
#  1   platform      18607 non-null  object
#  2   release_date  18607 non-null  object
#  3   meta_score    18607 non-null  int64
#  4   user_review   17528 non-null  float64
#  5   Rank          18607 non-null  int64
#  6   Platform      18607 non-null  object
#  7   Year          18196 non-null  float64
#  8   Genre         18607 non-null  object
#  9   Publisher     18598 non-null  object
#  10  NA_Sales      18607 non-null  float64
#  11  EU_Sales      18607 non-null  float64
#  12  JP_Sales      18607 non-null  float64
#  13  Other_Sales   18607 non-null  float64
#  14  Global_Sales  18607 non-null  float64
# dtypes: float64(7), int64(2), object(6)
# memory usage: 2.3+ MB

# %%
df.tail(20)
# Out:
#                                            name           platform  \
# 18587              Aquaman: Battle for Atlantis               Xbox
# 18588  Mucha Lucha! Mascaritas of the Lost Code   Game Boy Advance
# 18589                   Stake: Fortune Fighters               Xbox
# 18590                                HBO Boxing        PlayStation
# 18591                              KISS Pinball        PlayStation
# 18592              Tenkai Knights: Brave Battle                3DS
# 18593       Leisure Suit Larry: Box Office Bust           Xbox 360
# 18594       Leisure Suit Larry: Box Office Bust           Xbox 360
# 18595       Leisure Suit Larry: Box Office Bust                 PC
# 18596       Leisure Suit Larry: Box Office Bust                 PC
# 18597                                Game Party                Wii
# 18598                                   Cruis'n                Wii
# 18599      Gravity Games Bike: Street Vert Dirt      PlayStation 2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18607 entries, 0 to 18606
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          18607 non-null  object
#  1   platform      18607 non-null  object
#  2   release_date  18607 non-null  object
#  3   meta_score    18607 non-null  int64
#  4   user_review   17528 non-null  float64
#  5   Rank          18607 non-null  int64
#  6   Platform      18607 non-null  object
#  7   Year          18196 non-null  float64
#  8   Genre         18607 non-null  object
#  9   Publisher     18598 non-null  object
#  10  NA_Sales      18607 non-null  float64
#  11  EU_Sales      18607 non-null  float64
#  12  JP_Sales      18607 non-null  float64
#  13  Other_Sales   18607 non-null  float64
#  14  Global_Sales  18607 non-null  float64
# dtypes: float64(7), int64(2), object(6)
# memory usage: 2.3+ MB

# %%
# Conver year to int

# %%
df["Year"]=df["Year"].fillna(0).astype(np.int64)

# %%
df.head()
# Out:
#                                    name      platform release_date  \
# 0  The Legend of Zelda: Ocarina of Time   Nintendo 64    23-Nov-98
# 1  The Legend of Zelda: Ocarina of Time   Nintendo 64    23-Nov-98
# 2              Tony Hawk's Pro Skater 2   PlayStation    20-Sep-00
# 3              Tony Hawk's Pro Skater 2   PlayStation    20-Sep-00
# 4              Tony Hawk's Pro Skater 2   PlayStation    20-Sep-00
#
#    meta_score  user_review  Rank Platform  Year   Genre   Publisher  NA_Sales  \
# 0          99          9.1    95      N64  1998  Action    Nintendo      4.10
# 1          99          9.1   269      3DS  2011  Action    Nintendo      2.03
# 2          98          7.4   226       PS  2000  Sports  Activision      3.05
# 3          98          7.4  1713      GBA  2001  Sports  Activision      0.85
# 4          98          7.4  2707      N64  2001  Sports  Activision      0.59
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
#df ['Year']= df.to_string()

# %%
df["Year"].max()
# Out:
# 2016

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# name            0
# platform        0
# release_date    0
# meta_score      0
# user_review     0
# Rank            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17519 entries, 0 to 18606
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          17519 non-null  object
#  1   platform      17519 non-null  object
#  2   release_date  17519 non-null  object
#  3   meta_score    17519 non-null  int64
#  4   user_review   17519 non-null  float64
#  5   Rank          17519 non-null  int64
#  6   Platform      17519 non-null  object
#  7   Year          17519 non-null  int64
#  8   Genre         17519 non-null  object
#  9   Publisher     17519 non-null  object
#  10  NA_Sales      17519 non-null  float64
#  11  EU_Sales      17519 non-null  float64
#  12  JP_Sales      17519 non-null  float64
#  13  Other_Sales   17519 non-null  float64
#  14  Global_Sales  17519 non-null  float64
# dtypes: float64(6), int64(3), object(6)
# memory usage: 2.1+ MB

# %% [markdown]
# ## <a name='Expl' > Exploratory Data Analysis (Uni-Variable) </a>

# %%
# To check null value 
(df.isna().sum() / len(df) * 100.00).hist()
# Out:
# <AxesSubplot:>

# %%
# Discover outliers with Quartile calculations (IQR)

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# meta_score        17.00
# user_review        1.60
# Rank            7133.50
# Year               7.00
# NA_Sales           0.35
# EU_Sales           0.21
# JP_Sales           0.01
# Other_Sales        0.07
# Global_Sales       0.69
# dtype: float64

# %%
(df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))
# Out:
#        EU_Sales  Genre  Global_Sales  JP_Sales  NA_Sales  Other_Sales  \
# 0          True  False          True      True      True        False
# 1          True  False          True      True      True         True
# 2          True  False          True     False      True         True
# 3         False  False         False     False     False        False
# 4         False  False         False     False     False        False
# ...         ...    ...           ...       ...       ...          ...
# 18602     False  False         False     False     False        False
# 18603     False  False         False     False     False        False
# 18604     False  False         False     False     False        False
# 18605     False  False         False     False     False        False
# 18606     False  False         False     False     False        False
#
#        Platform  Publisher   Rank   Year  meta_score   name  platform  \
# ...

# %%
sns.boxplot(df['NA_Sales'])
# Out:
# <AxesSubplot:xlabel='NA_Sales'>

# %%
sns.boxplot(df['EU_Sales'])
# Out:
# <AxesSubplot:xlabel='EU_Sales'>

# %%
sns.boxplot(df['JP_Sales'])
# Out:
# <AxesSubplot:xlabel='JP_Sales'>

# %%
sns.boxplot(df['Year'])
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
df = df[df['Year'] > 1750]

# %%
df.shape
# Out:
# (17142, 15)

# %%
sns.boxplot(df['Global_Sales'])
# Out:
# <AxesSubplot:xlabel='Global_Sales'>

# %%
df[df['Global_Sales'] < 40]
# Out:
#             name platform release_date  meta_score  user_review  Rank  \
# 9595  Wii Sports      Wii    19-Nov-06          76          8.1     1
#
#      Platform  Year   Genre Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 9595      Wii  2006  Sports  Nintendo     41.49     29.02      3.77
#
#       Other_Sales  Global_Sales
# 9595         8.46         82.74

# %% [markdown]
# ## <a name='Explo' > Exploratory Data Analysis (Multi-Variable_Relationship) </a>

# %%
# correlation between user_review and Global_Sales
print(df['user_review'].corr(df['Global_Sales']))
# Out:
# 0.061721244557192065

# %%
#sns.pairplot(df)

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x='user_review', data= df)
# Out:
# <AxesSubplot:xlabel='user_review'>

# %%
print(df['Platform'].value_counts())
#df.corr()
# Out:
# PS2     2545
# X360    2249
# PS3     2086
# XB      1535
# PC      1512
# Wii     1125
# DS      1109
# GC      1099
# PSP      965
# GBA      691
# PS4      483
# XOne     377
# 3DS      321
# PSV      292
# PS       279
# WiiU     216
# N64      115
# SNES      31
# DC        28
# SAT       18
# 2600      16
# GB        15
# NES       14
# GEN       12
# NG         5
# SCD        2
# WS         2
# Name: Platform, dtype: int64

# %%
plt.figure(figsize=(35,15))
sns.set(font_scale=2)
ax = sns.violinplot(x=df['Platform'], y=df['Global_Sales'], data=df)
ax.set(xlabel='Platform', ylabel='Global Sales', title='')
plt.show()

# %%
#sns.set_theme(style="darkgrid")
#sns.displot(
#    df, x=df['Platform'], col=df["Global_Sales"], row=df["Year"],
#    binwidth=3, height=3, facet_kws=dict(margin_titles=True),
#)

# %%
gameNames = df['name'].unique()
publisherNames = df['Publisher'].unique()
platformNames = df['Platform'].unique()
genreNames = df['Genre'].unique()
print("There are",len(gameNames),"games in the dataset.")
print("There are",len(publisherNames),"publishers in the dataset.")
print("There are",len(platformNames),"platforms in the dataset.")
print("There are",len(genreNames),"different genres in the dataset.")
# Out:
# There are 4339 games in the dataset.
# There are 275 publishers in the dataset.
# There are 27 platforms in the dataset.
# There are 12 different genres in the dataset.

# %%
p_jp = pd.DataFrame(df.groupby("Platform")[["JP_Sales"]].sum().sort_values(by=['JP_Sales'],ascending=[False]).reset_index().head(5))
p_jp.columns = ["JP_Platform", "JP_Sales"]

# %%
p_jp.columns
# Out:
# Index(['JP_Platform', 'JP_Sales'], dtype='object')

# %%
p_na = pd.DataFrame(df.groupby("Platform")[["NA_Sales"]].sum().sort_values(by=['NA_Sales'],ascending=[False]).reset_index().head(5))
p_na.columns = ["NA_Platform", "NA_Sales"]

# %%
p_na.columns
# Out:
# Index(['NA_Platform', 'NA_Sales'], dtype='object')

# %%
o = pd.concat([p_jp, p_na])

# %%
o
# Out:
#   JP_Platform  JP_Sales NA_Platform  NA_Sales
# 0         PS3    139.82         NaN       NaN
# 1         PS2    120.26         NaN       NaN
# 2          DS     81.66         NaN       NaN
# 3          PS     75.08         NaN       NaN
# 4         Wii     58.66         NaN       NaN
# 0         NaN       NaN        X360   1534.98
# 1         NaN       NaN         PS2   1279.66
# 2         NaN       NaN         PS3    988.53
# 3         NaN       NaN         Wii    622.46
# 4         NaN       NaN          XB    425.27

# %%
plt.bar(x = p_jp["JP_Platform"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-205-ac88a08a3141> in <module>
# ----> 1 plt.bar(x = p_jp["JP_Platform"])
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
p_eu = pd.DataFrame(df.groupby("Platform")[["EU_Sales"]].sum().sort_values(by=['EU_Sales'],ascending=[False]).reset_index().head(5))
p_eu.rename(columns = {'Platform':'Platform_EU'})
# Out:
#   Platform_EU  EU_Sales
# 0         PS3    916.17
# 1        X360    739.12
# 2         PS2    636.74
# 3         Wii    365.83
# 4         PS4    261.25

# %%
p_o = pd.DataFrame(df.groupby("Platform")[["Other_Sales"]].sum().sort_values(by=['Other_Sales'],ascending=[False]).reset_index().head(5))
p_o.rename(columns = {'Platform':'Platform_Other'})
# Out:
#   Platform_Other  Other_Sales
# 0            PS2       417.37
# 1            PS3       375.19
# 2           X360       221.67
# 3            Wii       105.95
# 4            PS4        88.16

# %%
p_glp = pd.DataFrame(df.groupby("Platform")[["Global_Sales"]].sum().sort_values(by=['Global_Sales'],ascending=[False]).reset_index().head(5))
p_glp.rename(columns = {'Platform':'Platform_Global'})
# Out:
#   Platform_Global  Global_Sales
# 0            X360       2519.89
# 1             PS2       2453.75
# 2             PS3       2419.55
# 3             Wii       1152.87
# 4              DS        672.28

# %%
data=pd.concat([p_jp,p_na, p_eu, p_o, p_glp])
data.head(5)
# Out:
#   Platform  JP_Sales  NA_Sales  EU_Sales  Other_Sales  Global_Sales
# 0      PS3    139.82       NaN       NaN          NaN           NaN
# 1      PS2    120.26       NaN       NaN          NaN           NaN
# 2       DS     81.66       NaN       NaN          NaN           NaN
# 3       PS     75.08       NaN       NaN          NaN           NaN
# 4      Wii     58.66       NaN       NaN          NaN           NaN

# %%
sns.set(rc={'figure.figsize': (20.7,15.27)})
sns.barplot(x = p_jp['JP_Platform'],y=p_jp['JP_Sales'],data=df);
sns.barplot(x = p_na['NA_Platform'],y=p_na['NA_Sales'],data=df);

# %%
sns.set(rc={'figure.figsize': (25.7,20.27)})
df.boxplot(by = 'Platform');

# %%
top5= pd.DataFrame(df.groupby("Platform")[["Global_Sales"]].sum().sort_values(by=['Global_Sales'],ascending=[False]).reset_index())
top_5PG = top5.head(5)
top_5PG
# Out:
#   Platform  Global_Sales
# 0     X360       2554.33
# 1      PS2       2508.52
# 2      PS3       2441.56
# 3      Wii       1222.23
# 4       DS        678.53

# %%
g_jp = pd.DataFrame(df.groupby("Genre")[["JP_Sales"]].sum().sort_values(by=['JP_Sales'],ascending=[False]).reset_index())
g_jp.rename(columns = {'Genre':'Genre_JP'})

g_na = pd.DataFrame(df.groupby("Genre")[["NA_Sales"]].sum().sort_values(by=['NA_Sales'],ascending=[False]).reset_index())
g_na.rename(columns = {'Genre':'Platform_NA'})

g_eu = pd.DataFrame(df.groupby("Genre")[["EU_Sales"]].sum().sort_values(by=['EU_Sales'],ascending=[False]).reset_index())
g_eu.rename(columns = {'Genre':'Platform_EU'})

g_o = pd.DataFrame(df.groupby("Genre")[["Other_Sales"]].sum().sort_values(by=['Other_Sales'],ascending=[False]).reset_index())
g_o.rename(columns = {'Genre':'Platform_Other'})

g_glp = pd.DataFrame(df.groupby("Genre")[["Global_Sales"]].sum().sort_values(by=['Global_Sales'],ascending=[False]).reset_index())
g_glp.rename(columns = {'Genre':'Platform_Global'})

data=pd.concat([g_jp,g_na, g_eu, g_o, g_glp],axis=1)
data.head(5)
# Out:
#           Genre  JP_Sales    Genre  NA_Sales         Genre  EU_Sales    Genre  \
# 0        Action    188.85   Action   1971.99        Action   1324.98   Action
# 1  Role-Playing    185.70   Sports   1400.99        Sports    743.29   Sports
# 2        Sports     68.24  Shooter   1204.80       Shooter    735.47  Shooter
# 3      Platform     63.08   Racing    500.61        Racing    362.58   Racing
# 4       Shooter     48.23     Misc    470.64  Role-Playing    243.15     Misc
#
#    Other_Sales         Genre  Global_Sales
# 0       492.41        Action       3978.83
# 1       320.69        Sports       2533.75
# 2       242.07       Shooter       2230.75
# 3       120.96        Racing       1025.27
# 4        86.38  Role-Playing        939.89

# %%
top5= pd.DataFrame(df.groupby("Genre")[["Global_Sales"]].sum().sort_values(by=['Global_Sales'],ascending=[False]).reset_index())
top5.head(5)
# Out:
#           Genre  Global_Sales
# 0        Action       3978.83
# 1        Sports       2533.75
# 2       Shooter       2230.75
# 3        Racing       1025.27
# 4  Role-Playing        939.89

# %%
year_u = df['Year'].unique()
year2= []
for i in year_u:
    if i >= 2000:
        year2.append(i)
#print(year2)
x= df['Genre'].to_list

# %%
#plt.plot(year2, x)

#sns.barplot(x=year2, y=df['Global_Sales'], hue= df['Platform'] , data=df, saturation=0.8)

# %%
plt.figure(figsize=(25, 8), dpi=80)
plt.scatter(df['Platform'],df['Global_Sales'])
plt.xlabel('Platform')
plt.ylabel("Global_Sales")
plt.show()

# %% [markdown]
# ## <a name='Ques' > Questions & Insights </a>
